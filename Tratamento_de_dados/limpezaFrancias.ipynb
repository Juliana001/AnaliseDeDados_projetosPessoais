# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliana001/AnaliseDeDados_projetosPessoais/blob/main/Tratamento_de_dados/limpezaFrancias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Juliana](https://drive.google.com/uc?export=view&id=1PRtZkH3XKEHD7ROx0NvjS8SkubI-RKdu)

# %% [markdown]
# #1- importação das bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #2 - importação do dataset

# %%
df = pd.read_csv('/content/DatasetFragrancias.csv')
display(df)
# Out:
#                                                      url  \
# 0      https://www.fragrantica.com/perfume/xerjoff/ac...
# 1      https://www.fragrantica.com/perfume/jean-paul-...
# 2      https://www.fragrantica.com/perfume/jean-paul-...
# 3      https://www.fragrantica.com/perfume/bruno-bana...
# 4      https://www.fragrantica.com/perfume/jean-paul-...
# ...                                                  ...
# 24058  https://www.fragrantica.com/perfume/o-boticari...
# 24059  https://www.fragrantica.com/perfume/sultan-pas...
# 24060  https://www.fragrantica.com/perfume/darkbeat-p...
# 24061  https://www.fragrantica.com/perfume/parfumerie...
# 24062  https://www.fragrantica.com/perfume/nilafar-du...
#
#                               Perfume                Brand  Country  Gender  \
# 0      accento-overdose-pride-edition              xerjoff    Italy  unisex
# 1                classique-pride-2024   jean-paul-gaultier   France   women
# ...

# %% [markdown]
# #3 - limpeza do dataset

# %%
df = df.drop('url', axis=1)

# %%
display(df)
# Out:
#                               Perfume                Brand  Country  Gender  \
# 0      accento-overdose-pride-edition              xerjoff    Italy  unisex
# 1                classique-pride-2024   jean-paul-gaultier   France   women
# 2                classique-pride-2023   jean-paul-gaultier   France  unisex
# 3                   pride-edition-man         bruno-banani  Germany     men
# 4             le-male-pride-collector   jean-paul-gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o-boticario   Brazil   women
# 24059                 cheval-d-arabie  sultan-pasha-attars       UK  unisex
# 24060                           khaox     darkbeat-parfums    Spain  unisex
# 24061                       aoud-no-1  parfumerie-bruckner  Germany  unisex
# 24062        narmar-extrait-de-parfum       nilafar-du-nil    Egypt     men
#
#       Rating Value  Rating Count    Year  \
# ...

# %%
df = df.drop(['Perfumer1', 'Perfumer2'], axis=1)

# %%
display(df)
# Out:
#                               Perfume                Brand  Country  Gender  \
# 0      accento-overdose-pride-edition              xerjoff    Italy  unisex
# 1                classique-pride-2024   jean-paul-gaultier   France   women
# 2                classique-pride-2023   jean-paul-gaultier   France  unisex
# 3                   pride-edition-man         bruno-banani  Germany     men
# 4             le-male-pride-collector   jean-paul-gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o-boticario   Brazil   women
# 24059                 cheval-d-arabie  sultan-pasha-attars       UK  unisex
# 24060                           khaox     darkbeat-parfums    Spain  unisex
# 24061                       aoud-no-1  parfumerie-bruckner  Germany  unisex
# 24062        narmar-extrait-de-parfum       nilafar-du-nil    Egypt     men
#
#       Rating Value  Rating Count    Year  \
# ...

# %%
df_copia = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24063 entries, 0 to 24062
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Perfume       24063 non-null  object
#  1   Brand         24063 non-null  object
#  2   Country       24063 non-null  object
#  3   Gender        24063 non-null  object
#  4   Rating Value  24063 non-null  object
#  5   Rating Count  24063 non-null  int64
#  6   Year          22026 non-null  float64
#  7   Top           24063 non-null  object
#  8   Middle        24063 non-null  object
#  9   Base          24063 non-null  object
#  10  mainaccord1   24063 non-null  object
#  11  mainaccord2   24050 non-null  object
#  12  mainaccord3   23949 non-null  object
#  13  mainaccord4   23675 non-null  object
#  14  mainaccord5   23082 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 2.8+ MB

# %%
df['Year'].unique()
# Out:
# array([2022., 2024., 2023., 2019., 2020.,   nan, 2004., 2021., 2009.,
#        2016., 2018., 2003., 2000., 2011., 2017., 2014., 2013., 2008.,
#        2015., 2012., 2006., 2002., 2005., 2001., 2010., 1994., 1999.,
#        2007., 1998., 1989., 1995., 1996., 1988., 1981., 1997., 1991.,
#        1993., 1984., 1982., 1936., 1983., 1978., 1973., 1992., 1990.,
#        1985., 1853., 1960., 1975., 1979., 1986., 1901., 1921., 1828.,
#        1948., 1953., 1886., 1967., 1976., 1968., 1959., 1971., 1969.,
#        1987., 1949., 1974., 1980., 1914., 1970., 1965., 1950., 1847.,
#        1977., 1941., 1890., 1932., 1907., 1934., 1845., 1946., 1930.,
#        1850., 1801., 1872., 1935., 1943., 1942., 1899., 1927., 1923.,
#        1966., 1913., 1952., 1955., 1954., 1924., 1830., 1972., 1944.,
#        1956., 1800., 1929., 1862., 1919., 1961., 1964., 1951., 1786.,
#        1909., 1933., 1781., 1925., 1910., 1963., 1832., 1889., 1938.,
# ...

# %%
linha = df[df['Year'].isna()]

# %%
display(linha)
# Out:
#                                   Perfume                   Brand  \
# 12                            cherry-lady                 brocard
# 40                                   oshi                   bi-es
# 43                      charming-snowdrop  pokrovka-trading-house
# 68                 muguet-du-bonheur-2021                   caron
# 76                           sankai-black                   bi-es
# ...                                   ...                     ...
# 24015                     arabian-leather             arabian-oud
# 24022            mahora-extrait-de-parfum                guerlain
# 24029                  amazing-mukhallath    al-haramain-perfumes
# 24049  narciso-rodriguez-musc-oil-for-him       narciso-rodriguez
# 24051                       zimaya-wujood                   afnan
#
#             Country  Gender Rating Value  Rating Count  Year  \
# 12           Russia   women         2,64            39   NaN
# ...

# %%
df = df.drop(['Year'], axis=1)

# %%
display(df)
# Out:
#                               Perfume                Brand  Country  Gender  \
# 0      accento-overdose-pride-edition              xerjoff    Italy  unisex
# 1                classique-pride-2024   jean-paul-gaultier   France   women
# 2                classique-pride-2023   jean-paul-gaultier   France  unisex
# 3                   pride-edition-man         bruno-banani  Germany     men
# 4             le-male-pride-collector   jean-paul-gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o-boticario   Brazil   women
# 24059                 cheval-d-arabie  sultan-pasha-attars       UK  unisex
# 24060                           khaox     darkbeat-parfums    Spain  unisex
# 24061                       aoud-no-1  parfumerie-bruckner  Germany  unisex
# 24062        narmar-extrait-de-parfum       nilafar-du-nil    Egypt     men
#
#       Rating Value  Rating Count  \
# ...

# %%
df = df.drop(['Rating Value', 'Rating Count'], axis=1)

# %% [markdown]
# # 4 - organização do dataset

# %%
df = df.replace('-', ' ', regex=True)

# %%
display(df)
# Out:
#                               Perfume                Brand  Country  Gender  \
# 0      accento overdose pride edition              xerjoff    Italy  unisex
# 1                classique pride 2024   jean paul gaultier   France   women
# 2                classique pride 2023   jean paul gaultier   France  unisex
# 3                   pride edition man         bruno banani  Germany     men
# 4             le male pride collector   jean paul gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o boticario   Brazil   women
# 24059                 cheval d arabie  sultan pasha attars       UK  unisex
# 24060                           khaox     darkbeat parfums    Spain  unisex
# 24061                       aoud no 1  parfumerie bruckner  Germany  unisex
# 24062        narmar extrait de parfum       nilafar du nil    Egypt     men
#
# ...

# %%
df = df.rename(columns = {
    'Brand' : 'marca',
    'Fragrance' : 'fragrancia',
    'Gender' : 'genero',
    'Top' : 'topo',
    'Middle' : 'corpo',
    'Base' : 'fundo',
    'mainaccord1' : 'acorde1',
    'mainaccord2' : 'acorde2',
    'mainaccord3' : 'acorde3',
    'mainaccord4' : 'acorde4',
    'mainaccord5' : 'acorde5'
    }
               )

# %%
display(df)
# Out:
#                               Perfume                marca  Country  genero  \
# 0      accento overdose pride edition              xerjoff    Italy  unisex
# 1                classique pride 2024   jean paul gaultier   France   women
# 2                classique pride 2023   jean paul gaultier   France  unisex
# 3                   pride edition man         bruno banani  Germany     men
# 4             le male pride collector   jean paul gaultier   France     men
# ...                               ...                  ...      ...     ...
# 24058                        floratta          o boticario   Brazil   women
# 24059                 cheval d arabie  sultan pasha attars       UK  unisex
# 24060                           khaox     darkbeat parfums    Spain  unisex
# 24061                       aoud no 1  parfumerie bruckner  Germany  unisex
# 24062        narmar extrait de parfum       nilafar du nil    Egypt     men
#
# ...

# %%
df.to_csv('datasetFragranciasLimpo.csv', index = False)
